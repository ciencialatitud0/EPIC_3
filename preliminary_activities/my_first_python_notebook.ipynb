# %% [markdown]
# # Preliminary activities for python tutorials (10/10/2022)
#
# The following commands will help you set up your Google Colab working space.
#
# **Note: in step 5, please clic on "Connect to Google Drive" and then on "Allow" when asked about letting Colab access your Google Drive.**
#
# ### 1. Check where you are, you can use bash commands in a jupyter notebook with ! e.g.

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# ### 2. Check python and conda version

# %%
# !python --version
# Out:
# Python 3.7.14

# %% [markdown]
# ### 3. Now, let's import a few libraries, there should be no errors

# %%
# Importing libraries, note that '#' can be used to comment your code
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ### 4. Now, let's make a simple plot

# %%
# The line below forces the notebook to display the plots we are making
# %matplotlib inline

x = np.arange(-2*math.pi,+2*math.pi,0.01)
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))

# %% [markdown]
# ### 5. Now let's try to read an image from Google Drive, but first we need to mount the drive as follows:

# %%
from google.colab import drive
drive.mount('/content/drive')


# To display the contents
# !ls "/content/drive/My Drive"
# Out:
# Mounted at /content/drive
# 'Colab Notebooks'
#  EPIC-2-preliminary-programme.gsheet
#  EPIC-2-programme.gsheet
#  EPIC.gform
#  LatitudCero-En.gsite
#  LatitudCero.gsite
#  Posters_Certificados
# 'Registro de charlas para conferencistas - Talk registration form (File responses)'

# %% [markdown]
# ### 6. And now we import the jpg image and display it.
#
#
# **Note: Upload any jpg image into your Colab Notebooks folder. You can find the jpg image of the worked example here:**
#
# https://github.com/ciencialatitud0/EPIC_2/blob/main/Day0/Cotopaxi_volcano.jpeg

# %%
import matplotlib.cbook as cbook

# The image below was taken from: https://github.com/ciencialatitud0/EPIC_2/blob/main/Day0/Cotopaxi_volcano.jpeg

image_file = cbook.get_sample_data('/content/drive/My Drive/Colab Notebooks/Cotopaxi_volcano.jpeg')
image = plt.imread(image_file)

fig, ax = plt.subplots()
ax.imshow(image)
#ax.axis('off')  # clear x- and y-axes
plt.show()

# %% [markdown]
# ### 7. Let's try now to import it as an array:

# %%
import cv2

im = cv2.imread("/content/drive/My Drive/Colab Notebooks/Cotopaxi_volcano.jpeg")
print(type(im), np.shape(im))
# Out:
# <class 'numpy.ndarray'> (462, 900, 3)

# %% [markdown]
# ### 8. And we can make some plots of the different colour layers:

# %%
fig, ax = plt.subplots()
ax.imshow(im[:,:,0], cmap="Blues")
#ax.axis('off')  # clear x- and y-axes
plt.show()

fig, ax = plt.subplots()
ax.imshow(im[:,:,1], cmap="Greens")
#ax.axis('off')  # clear x- and y-axes
plt.show()

fig, ax = plt.subplots()
ax.imshow(im[:,:,2], cmap="Reds")
#ax.axis('off')  # clear x- and y-axes
plt.show()

# %% [markdown]
# ### 9. We will use several libraries for the tutorial in EPIC 2, some of them are installed by default:

# %%
import numpy
import scipy
import matplotlib
import h5py
import imageio
import pandas
import astropy

# %% [markdown]
# ### 10. As we can see, there are no errors. Now, the following does not work:

# %%
import yt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-10-2d2292a375dc> in <module>
# ----> 1 import yt
#
# ModuleNotFoundError: No module named 'yt'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ### 11. But, it tells us what to do:

# %%
# !pip install yt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting yt
#   Downloading yt-4.1.0-cp37-cp37m-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (39.1 MB)
#      |████████████████████████████████| 39.1 MB 172 kB/s
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from yt) (7.1.2)
# Requirement already satisfied: tomli>=1.2.3 in /usr/local/lib/python3.7/dist-packages (from yt) (2.0.1)
# Requirement already satisfied: importlib-metadata>=1.4 in /usr/local/lib/python3.7/dist-packages (from yt) (5.0.0)
# Collecting cmyt>=0.2.2
#   Downloading cmyt-1.0.4-py3-none-any.whl (30 kB)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.7/dist-packages (from yt) (21.3)
# Requirement already satisfied: numpy>=1.14.5 in /usr/local/lib/python3.7/dist-packages (from yt) (1.21.6)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from yt) (3.0.9)
# Collecting tomli-w>=0.4.0
#   Downloading tomli_w-1.0.0-py3-none-any.whl (6.0 kB)
# Collecting unyt>=2.8.0
#   Downloading unyt-2.8.0-py2.py3-none-any.whl (98 kB)
#      |████████████████████████████████| 98 kB 11.3 MB/s
# Requirement already satisfied: matplotlib!=3.4.2,>=3.1 in /usr/local/lib/python3.7/dist-packages (from yt) (3.2.2)
# Collecting typing-extensions>=4.2.0
#   Downloading typing_extensions-4.4.0-py3-none-any.whl (26 kB)
# Requirement already satisfied: tqdm>=3.4.0 in /usr/local/lib/python3.7/dist-packages (from yt) (4.64.1)
# Requirement already satisfied: more-itertools>=8.4 in /usr/local/lib/python3.7/dist-packages (from yt) (8.14.0)
# Collecting colorspacious>=1.1.2
#   Downloading colorspacious-1.1.2-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=1.4->yt) (3.8.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.4.2,>=3.1->yt) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.4.2,>=3.1->yt) (2.8.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib!=3.4.2,>=3.1->yt) (0.11.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.1->matplotlib!=3.4.2,>=3.1->yt) (1.15.0)
# Requirement already satisfied: sympy>=1.2 in /usr/local/lib/python3.7/dist-packages (from unyt>=2.8.0->yt) (1.7.1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.7/dist-packages (from sympy>=1.2->unyt>=2.8.0->yt) (1.2.1)
# Installing collected packages: typing-extensions, colorspacious, unyt, tomli-w, cmyt, yt
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing-extensions 4.1.1
#     Uninstalling typing-extensions-4.1.1:
#       Successfully uninstalled typing-extensions-4.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# thinc 8.1.2 requires typing-extensions<4.2.0,>=3.7.4.1; python_version < "3.8", but you have typing-extensions 4.4.0 which is incompatible.
# spacy 3.4.1 requires typing-extensions<4.2.0,>=3.7.4; python_version < "3.8", but you have typing-extensions 4.4.0 which is incompatible.
# confection 0.0.2 requires typing-extensions<4.2.0,>=3.7.4.1; python_version < "3.8", but you have typing-extensions 4.4.0 which is incompatible.
# Successfully installed cmyt-1.0.4 colorspacious-1.1.2 tomli-w-1.0.0 typing-extensions-4.4.0 unyt-2.8.0 yt-4.1.0

# %%
import yt

# %% [markdown]
# ### 12. It works now, and another example:

# %%
import colt
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-13-ec8544110d3c> in <module>
# ----> 1 import colt
#
# ModuleNotFoundError: No module named 'colt'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %%
# !pip install pycolt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pycolt
#   Downloading pycolt-0.5.3.tar.gz (68 kB)
#      |████████████████████████████████| 68 kB 4.8 MB/s
# Building wheels for collected packages: pycolt
#   Building wheel for pycolt (setup.py) ... done
#   Created wheel for pycolt: filename=pycolt-0.5.3-py2.py3-none-any.whl size=66130 sha256=0f2cbdb7cd852d9d04e453de547ecca956cee7cded0374a2b13de50266503be7
#   Stored in directory: /root/.cache/pip/wheels/4e/d6/d1/e033f80d4ff8a0dfbd415d8939d74f087f69ea8117686fbaae
# Successfully built pycolt
# Installing collected packages: pycolt
# Successfully installed pycolt-0.5.3

# %%
import colt

# %% [markdown]
# ### 13. And pycolt also works now!
