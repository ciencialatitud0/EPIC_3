# %% [markdown]
# <a href="https://colab.research.google.com/github/wbandabarragan/EPIC_3/blob/main/Day_1/preliminary_activities/my_first_notebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Preliminary activities (14/08/2023)
#
# 1. Which operating system do you have?
#
#
# 2. Google Colab example.
#
#
# 3. Testing Anaconda installation, plus an example.
#
#
# 4. Questions, problems?
#
# ### 1. Check where you are, you can use bash commands in a jupyter notebook with ! e.g.

# %%
# !pwd
# Out:
# /content

# %% [markdown]
# ### 2. Check python and conda version

# %%
# !python --version
# Out:
# Python 3.10.12

# %% [markdown]
# ### 3. Now, let's import a few libraries, there should be no errors

# %%
# Importing libraries, note that '#' can be used to comment your code
import numpy as np
import matplotlib.pyplot as plt
import math

# %% [markdown]
# ### 4. Now, let's make a simple plot

# %%
# The line below forces the notebook to display the plots we are making
# %matplotlib inline

x = np.arange(-2*math.pi,+2*math.pi,0.01)
plt.plot(x,np.sin(x))
plt.plot(x,np.cos(x))

# %% [markdown]
# ### 5. Now let's try to read an image from GDrive, but first we need to mount the drive as follows:

# %%
from google.colab import drive
drive.mount('/content/drive')


# To display the contents
# !ls "/content/drive/My Drive"
# Out:
# Mounted at /content/drive
#  BANDA_BARRAGAN_WLADIMIR_EDUARDO_Cedula.pdf
#  BANDA_BARRAGAN_WLADIMIR_EDUARDO_Desempeno.pdf
#  BANDA_BARRAGAN_WLADIMIR_EDUARDO_Educacion1.pdf
#  BANDA_BARRAGAN_WLADIMIR_EDUARDO_Educacion2.pdf
#  BANDA_BARRAGAN_WLADIMIR_EDUARDO_ExpDireccion.pdf
#  BANDA_BARRAGAN_WLADIMIR_EDUARDO_ExpDocente.pdf
#  BANDA_BARRAGAN_WLADIMIR_EDUARDO_Expgestion.pdf
#  BANDA_BARRAGAN_WLADIMIR_EDUARDO_Expprofesional.pdf
#  BANDA_BARRAGAN_WLADIMIR_EDUARDO_Expvinculacion.pdf
#  BANDA_BARRAGAN_WLADIMIR_EDUARDO_Formulario.pdf
#  BANDA_BARRAGAN_WLADIMIR_EDUARDO_Ingles.pdf
#  BANDA_BARRAGAN_WLADIMIR_EDUARDO_Instruccion.pdf
#  BANDA_BARRAGAN_WLADIMIR_EDUARDO_Investigacion.pdf
# 'BANDA_BARRAGAN_WLADIMIR_EDUARDO_Ponencias (1).pdf'
#  BANDA_BARRAGAN_WLADIMIR_EDUARDO_Ponencias.pdf
#  BANDA_BARRAGAN_WLADIMIR_EDUARDO_Premios.pdf
#  BANDA_BARRAGAN_WLADIMIR_EDUARDO_Publicaciones.pdf
#  BANDA_BARRAGAN_WLADIMIR_EDUARDO_Revisor.pdf
# 'Colab Notebooks'
#  domanda-Casavecchia-Benedetta.pdf
#  Job_applications_WBandaBarragan.gsheet
# 'Quantum mechanics Quiz 1.gform'
# 'Quantum mechanics Quiz 2.gform'
# 'Quiz 2 - Quantum mechanics.gform'

# %% [markdown]
# ### 6. And now we import the jpg image and display it:

# %%
import matplotlib.cbook as cbook

# The image below was taken from: https://en.wikipedia.org/wiki/Cotopaxi#/media/File:Cotopaxi_volcano_2008-06-27T1322.jpg

image_file = cbook.get_sample_data('/content/drive/My Drive/Colab Notebooks/Cotopaxi_volcano.jpeg')
image = plt.imread(image_file)

fig, ax = plt.subplots()
ax.imshow(image)
#ax.axis('off')  # clear x- and y-axes
plt.show()

# %% [markdown]
# ### 7. Let's try now to import it as an array:

# %%
import cv2

im = cv2.imread("/content/drive/My Drive/Colab Notebooks/Cotopaxi_volcano.jpeg")
print(type(im), np.shape(im))
# Out:
# <class 'numpy.ndarray'> (462, 900, 3)

# %% [markdown]
# ### 8. And we can make some plots of the different colour layers:

# %%
fig, ax = plt.subplots()
ax.imshow(im[:,:,0], cmap="Blues")
#ax.axis('off')  # clear x- and y-axes
plt.show()

fig, ax = plt.subplots()
ax.imshow(im[:,:,1], cmap="Greens")
#ax.axis('off')  # clear x- and y-axes
plt.show()

fig, ax = plt.subplots()
ax.imshow(im[:,:,2], cmap="Reds")
#ax.axis('off')  # clear x- and y-axes
plt.show()

# %% [markdown]
# ### 9. We will use several libraries for the tutorial in EPIC 1, some of them are installed by default:

# %%
import numpy
import scipy
import matplotlib
import h5py
import imageio
import pandas
import astropy

# %% [markdown]
# ### 10. As we can see, there are no errors. Now, the following does not work:

# %%
import yt
import vtk
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-11-1471c93b270f> in <cell line: 1>()
# ----> 1 import yt
#       2 import vtk
#
# ModuleNotFoundError: No module named 'yt'
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# "Open Examples" button below.
# ---------------------------------------------------------------------------

# %% [markdown]
# ### 11. But, it tells us what to do:

# %%
# !pip install yt
# Out:
# Collecting yt
#   Downloading yt-4.2.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (38.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.2/38.2 MB 15.7 MB/s eta 0:00:00
# Collecting cmyt>=1.1.2 (from yt)
#   Downloading cmyt-1.3.1-py3-none-any.whl (31 kB)
# Collecting ewah-bool-utils>=1.0.2 (from yt)
#   Downloading ewah_bool_utils-1.0.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 30.2 MB/s eta 0:00:00
# Collecting ipywidgets>=8.0.0 (from yt)
#   Downloading ipywidgets-8.1.0-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.3/139.3 kB 15.0 MB/s eta 0:00:00
# Requirement already satisfied: matplotlib!=3.4.2,>=3.2 in /usr/local/lib/python3.10/dist-packages (from yt) (3.7.1)
# Requirement already satisfied: more-itertools>=8.4 in /usr/local/lib/python3.10/dist-packages (from yt) (10.1.0)
# Requirement already satisfied: numpy>=1.17.5 in /usr/local/lib/python3.10/dist-packages (from yt) (1.23.5)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.10/dist-packages (from yt) (23.1)
# Requirement already satisfied: pillow>=6.2.1 in /usr/local/lib/python3.10/dist-packages (from yt) (9.4.0)
# Collecting tomli-w>=0.4.0 (from yt)
#   Downloading tomli_w-1.0.0-py3-none-any.whl (6.0 kB)
# Requirement already satisfied: tqdm>=3.4.0 in /usr/local/lib/python3.10/dist-packages (from yt) (4.66.0)
# Collecting unyt<3.0,>=2.9.2 (from yt)
#   Downloading unyt-2.9.5-py2.py3-none-any.whl (118 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.0/119.0 kB 12.6 MB/s eta 0:00:00
# Requirement already satisfied: tomli>=1.2.3 in /usr/local/lib/python3.10/dist-packages (from yt) (2.0.1)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.10/dist-packages (from yt) (4.7.1)
# Collecting comm>=0.1.3 (from ipywidgets>=8.0.0->yt)
#   Downloading comm-0.1.4-py3-none-any.whl (6.6 kB)
# Requirement already satisfied: ipython>=6.1.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=8.0.0->yt) (7.34.0)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=8.0.0->yt) (5.7.1)
# Collecting widgetsnbextension~=4.0.7 (from ipywidgets>=8.0.0->yt)
#   Downloading widgetsnbextension-4.0.8-py3-none-any.whl (2.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 84.6 MB/s eta 0:00:00
# Requirement already satisfied: jupyterlab-widgets~=3.0.7 in /usr/local/lib/python3.10/dist-packages (from ipywidgets>=8.0.0->yt) (3.0.8)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.4.2,>=3.2->yt) (1.1.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.4.2,>=3.2->yt) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.4.2,>=3.2->yt) (4.42.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.4.2,>=3.2->yt) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.4.2,>=3.2->yt) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib!=3.4.2,>=3.2->yt) (2.8.2)
# Requirement already satisfied: sympy>=1.5 in /usr/local/lib/python3.10/dist-packages (from unyt<3.0,>=2.9.2->yt) (1.12)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->yt) (67.7.2)
# Collecting jedi>=0.16 (from ipython>=6.1.0->ipywidgets>=8.0.0->yt)
#   Downloading jedi-0.19.0-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 67.2 MB/s eta 0:00:00
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->yt) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->yt) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->yt) (3.0.39)
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->yt) (2.16.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->yt) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->yt) (0.1.6)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=6.1.0->ipywidgets>=8.0.0->yt) (4.8.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib!=3.4.2,>=3.2->yt) (1.16.0)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy>=1.5->unyt<3.0,>=2.9.2->yt) (1.3.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=6.1.0->ipywidgets>=8.0.0->yt) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=8.0.0->yt) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=6.1.0->ipywidgets>=8.0.0->yt) (0.2.6)
# Installing collected packages: widgetsnbextension, tomli-w, jedi, ewah-bool-utils, comm, unyt, ipywidgets, cmyt, yt
#   Attempting uninstall: widgetsnbextension
#     Found existing installation: widgetsnbextension 3.6.5
#     Uninstalling widgetsnbextension-3.6.5:
#       Successfully uninstalled widgetsnbextension-3.6.5
#   Attempting uninstall: ipywidgets
#     Found existing installation: ipywidgets 7.7.1
#     Uninstalling ipywidgets-7.7.1:
#       Successfully uninstalled ipywidgets-7.7.1
# Successfully installed cmyt-1.3.1 comm-0.1.4 ewah-bool-utils-1.0.2 ipywidgets-8.1.0 jedi-0.19.0 tomli-w-1.0.0 unyt-2.9.5 widgetsnbextension-4.0.8 yt-4.2.1

# %%
import yt

# %% [markdown]
# ### 12. And now it works!!
